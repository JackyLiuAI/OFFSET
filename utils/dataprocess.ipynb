# %%
import pandas as pd

# Create DataFrame based on extracted table content
data = {
    "Method": ["ENCODER [15] (AAAI’25)", "OFFSET (Ours)"],
    "Dresses R@10": [51.51, 57.86],
    "Dresses R@50": [76.95, 79.13],
    "Shirts R@10": [54.86, 62.81],
    "Shirts R@50": [74.93, 81.55],
    "Tops&Tees R@10": [62.01, 67.11],
    "Tops&Tees R@50": [80.88, 85.87],
    "Avg R@10": [56.13, 62.59],
    "Avg R@50": [77.59, 82.18],
}

df = pd.DataFrame(data)

# Save to Excel file
excel_path = "Table_Results.xlsx"
df.to_excel(excel_path, index=False)

excel_path
# Out:
# 'Table_Results.xlsx'
